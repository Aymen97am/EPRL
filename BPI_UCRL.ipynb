# %%
size = "S500A5H10" #size of the MDPs
int(size.split("S")[1].split("A")[0])
# Out:
# 500

# %%
from EPRL import EPRLAgent
from BPI_UCRL import BPI_UCRLAgent
import numpy as np
import pandas as pd
from rlberry.envs.finite.finite_deterministic_mdp import FiniteDMDP

# %%
S = 2
A = 2
H = 3
epsilon = 0.1
delta = 0.1
env = FiniteDMDP.Random(H, S, A, Rmax = 1)

# %%
env.get_Reachable()
# Out:
# [{0}, {0, 1}, {0, 1}]

# %%
params = {
    "delta": delta,
    "epsilon": epsilon,
    "stage_dependent": True,
    "period" : None,
}
agent = BPI_UCRLAgent(env, **params)
pi = agent.fit(1e6, period = None)
# Out:
# [INFO] [BPI_UCRL[worker: -1]] | max_global_step = 11722 | max_diameter = 4.12245290156988 | dw_time_elapsed = 3.0003715330021805 | Qstar_diameter = 0.1351231194968805 | avg_actions = 2.0 |

# %%
params = {
    "sampling_rule": "max_diameter", # "adaptive_max_coverage"
    "delta": delta,
    "epsilon": epsilon,
    "stage_dependent": True,
    "period" : None,
}
agent1 = EPRLAgent(env, **params)
pi1 = agent1.fit(1e6, period = None)
# Out:
# [INFO] [EPRL[worker: -1]] | max_global_step = 9823 | max_diameter = 0.23246162637747117 | dw_time_elapsed = 3.0000533389975317 | Qstar_diameter = 0.23247452352674847 | avg_actions = 1.8 | N_min = 1643.0 |
# [INFO] [EPRL[worker: -1]] | max_global_step = 19875 | max_diameter = 0.16699654829546026 | dw_time_elapsed = 6.000202474002435 | Qstar_diameter = 0.1669889557477715 | avg_actions = 1.6 | N_min = 3479.0 |
# [INFO] [EPRL[worker: -1]] | max_global_step = 29790 | max_diameter = 0.13254728620459155 | dw_time_elapsed = 9.000340393002261 | Qstar_diameter = 0.13254807259495793 | avg_actions = 1.4 | N_min = 6147.0 |
# [INFO] [EPRL[worker: -1]] | max_global_step = 40064 | max_diameter = 0.11118701604450495 | dw_time_elapsed = 12.000456581001345 | Qstar_diameter = 0.1111874495112879 | avg_actions = 1.4 | N_min = 6147.0 |

# %%
df = pd.DataFrame(D)

# %%
df
# Out:
#        name           tag     value  global_step
# 0      EPRL  max_diameter  6.000000            0
# 1      EPRL  max_diameter  6.000000            1
# 2      EPRL  max_diameter  6.000000            2
# 3      EPRL  max_diameter  5.844234            3
# 4      EPRL  max_diameter  5.844234            4
# ...     ...           ...       ...          ...
# 48544  EPRL  max_diameter  0.100001        48544
# 48545  EPRL  max_diameter  0.100000        48545
# 48546  EPRL  max_diameter  0.099999        48546
# 48547  EPRL  max_diameter  0.099998        48547
# 48548  EPRL  max_diameter  0.099996        48548
#
# [48549 rows x 4 columns]

# %%
agent.writer.__dict__["_data"].keys()
# Out:
# dict_keys(['max_diameter', 'dw_time_elapsed', 'Qstar_diameter', 'avg_actions', 'correct'])

# %%
agent.episode
# Out:
# 22417

# %%
agent.N_min
# Out:
# 1.0

# %%
#agent.UQ_hsa

# %%
#agent.LQ_hsa

# %%
agent.eval()
# Out:
# 1

# %%
params = {
    "sampling_rule": "max_diameter", # "adaptive_max_coverage"
    "delta": delta,
    "epsilon": epsilon,
    "stage_dependent": True,
    "period" : None,
}
agent1 = EPRLAgent(env, **params)
pi1 = agent1.fit(1e6, period = None)
# Out:
# Episode n°1, N_min = 0.0            #Max Qstar diameter = 42.274824729335904, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°2, N_min = 0.0            #Max Qstar diameter = 32.57705608412297, Max diameter = 40.775532828131865,            #Average active actions = 3.0
# Episode n°3, N_min = 0.0            #Max Qstar diameter = 35.61714684278085, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°4, N_min = 0.0            #Max Qstar diameter = 33.50721279125973, Max diameter = 40.775532828131865,            #Average active actions = 3.0
# Episode n°5, N_min = 0.0            #Max Qstar diameter = 36.6456127843573, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°6, N_min = 0.0            #Max Qstar diameter = 30.764261590697853, Max diameter = 39.76585057842265,            #Average active actions = 3.0
# ...

# %%
x = agent1.cumR

# %%
agent1.episode
# Out:
# 286

# %%
agent1.N_min
# Out:
# 7.0

# %%
agent1.eval()
# Out:
# 1

# %%
params = {
    "sampling_rule": "adaptive_max_coverage",
    "delta": delta,
    "epsilon": epsilon,
    "stage_dependent": True,
    "period" : None,
}
agent2 = EPRLAgent(env, **params)
pi1 = agent2.fit(1e6, period = None)
# Out:
# Episode n°1, N_min = 0.0            #Max Qstar diameter = 41.82737462688789, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°2, N_min = 0.0            #Max Qstar diameter = 41.988856502204015, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°3, N_min = 0.0            #Max Qstar diameter = 42.274824729335904, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°4, N_min = 0.0            #Max Qstar diameter = 42.274824729335904, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°5, N_min = 0.0            #Max Qstar diameter = 41.3602851600419, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# Episode n°6, N_min = 0.0            #Max Qstar diameter = 41.27119670485028, Max diameter = 42.44141271835858,            #Average active actions = 3.0
# ...

# %%
agent2.episode
# Out:
# 484

# %%
agent2.N_min
# Out:
# 21.0

# %%
agent2.eval()
# Out:
# 1
